# %% [markdown]
# ### 2.1. Configuração do Ambiente Importando as bibliotecas necessarias para Iniciar na Analise de dados , utilizando Pandas.

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ### 2.2. Leitura dos Dados

# %%
df = pd.read_csv('./titaniccsv.csv')

# %% [markdown]
# ## 2.3. Organização e Limpeza dos Dados
# ### 2.3.1. Visão Geral do Conjunto de Dados

# %%
df
# Out:
#       id_passageiro  classe  sobreviveu  \
# 0                 1       1           1
# 1                 2       1           1
# 2                 3       1           0
# 3                 4       1           0
# 4                 5       1           0
# ...             ...     ...         ...
# 1304           1305       3           0
# 1305           1306       3           0
# 1306           1307       3           0
# 1307           1308       3           0
# 1308           1309       3           0
#
#                                                  nome    sexo  idade  \
# 0                       Allen, Miss. Elisabeth Walton  female   29.0
# 1                      Allison, Master. Hudson Trevor    male    1.0
# 2                        Allison, Miss. Helen Loraine  female    2.0
# 3                Allison, Mr. Hudson Joshua Creighton    male   30.0
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female   25.0
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female   15.0
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male   27.0
# 1307                              Zakarian, Mr. Ortin    male   27.0
# 1308                               Zimmerman, Mr. Leo    male   29.0
#
#       irmaos_conjuges  pais_filhos bilhete    tarifa   cabine embarque bote  \
# 0                   0            0   24160  211.3375       B5        S    2
# 1                   1            2  113781  151.5500  C22 C26        S   11
# 2                   1            2  113781  151.5500  C22 C26        S  NaN
# 3                   1            2  113781  151.5500  C22 C26        S  NaN
# 4                   1            2  113781  151.5500  C22 C26        S  NaN
# ...               ...          ...     ...       ...      ...      ...  ...
# 1304                1            0    2665   14.4542      NaN        C  NaN
# 1305                1            0    2665   14.4542      NaN        C  NaN
# 1306                0            0    2656    7.2250      NaN        C  NaN
# 1307                0            0    2670    7.2250      NaN        C  NaN
# 1308                0            0  315082    7.8750      NaN        S  NaN
#
#       corpo                          destino
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 15 columns]

# %% [markdown]
# ### 2.3.2 Remoção de Colunas
# Remoção de colunas incompletas e/ou desnecessárias para a análise.

# %% [markdown]
# ### 2.3.3. Dados Ausentes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_passageiro    1309 non-null   int64
#  1   classe           1309 non-null   int64
#  2   sobreviveu       1309 non-null   int64
#  3   nome             1309 non-null   object
#  4   sexo             1309 non-null   object
#  5   idade            1046 non-null   float64
#  6   irmaos_conjuges  1309 non-null   int64
#  7   pais_filhos      1309 non-null   int64
#  8   bilhete          1309 non-null   object
#  9   tarifa           1308 non-null   float64
#  10  cabine           295 non-null    object
#  11  embarque         1307 non-null   object
#  12  bote             486 non-null    object
#  13  corpo            121 non-null    float64
#  14  destino          745 non-null    object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 153.5+ KB

# %%
df.isnull().sum()
# Out:
# id_passageiro         0
# classe                0
# sobreviveu            0
# nome                  0
# sexo                  0
# idade               263
# irmaos_conjuges       0
# pais_filhos           0
# bilhete               0
# tarifa                1
# cabine             1014
# embarque              2
# bote                823
# corpo              1188
# destino             564
# dtype: int64

# %%
df.describe()
# Out:
#        id_passageiro       classe   sobreviveu        idade  irmaos_conjuges  \
# count    1309.000000  1309.000000  1309.000000  1046.000000      1309.000000
# mean      655.000000     2.294882     0.381971    29.897706         0.498854
# std       378.020061     0.837836     0.486055    14.414973         1.041658
# min         1.000000     1.000000     0.000000     0.000000         0.000000
# 25%       328.000000     2.000000     0.000000    21.000000         0.000000
# 50%       655.000000     3.000000     0.000000    28.000000         0.000000
# 75%       982.000000     3.000000     1.000000    39.000000         1.000000
# max      1309.000000     3.000000     1.000000    80.000000         8.000000
#
#        pais_filhos       tarifa       corpo
# count  1309.000000  1308.000000  121.000000
# mean      0.385027    33.295479  160.809917
# std       0.865560    51.758668   97.696922
# min       0.000000     0.000000    1.000000
# 25%       0.000000     7.895800   72.000000
# 50%       0.000000    14.454200  155.000000
# 75%       0.000000    31.275000  256.000000
# max       9.000000   512.329200  328.000000

# %%
print(df.value_counts())
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### 2.3.3.1 Idades Ausentes , Feita a substituição dos dados vazios pela média das idades na época.

# %%
df['idade'].mean()
# Out:
# 29.89770554493308

# %%
df.fillna(df.mean())
# Out:
#       id_passageiro  classe  sobreviveu  \
# 0                 1       1           1
# 1                 2       1           1
# 2                 3       1           0
# 3                 4       1           0
# 4                 5       1           0
# ...             ...     ...         ...
# 1304           1305       3           0
# 1305           1306       3           0
# 1306           1307       3           0
# 1307           1308       3           0
# 1308           1309       3           0
#
#                                                  nome    sexo      idade  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.000000
# 1                      Allison, Master. Hudson Trevor    male   1.000000
# 2                        Allison, Miss. Helen Loraine  female   2.000000
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.000000
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.000000
# ...                                               ...     ...        ...
# 1304                             Zabour, Miss. Hileni  female  15.000000
# 1305                            Zabour, Miss. Thamine  female  29.897706
# 1306                        Zakarian, Mr. Mapriededer    male  27.000000
# 1307                              Zakarian, Mr. Ortin    male  27.000000
# 1308                               Zimmerman, Mr. Leo    male  29.000000
#
#       irmaos_conjuges  pais_filhos bilhete    tarifa   cabine embarque bote  \
# 0                   0            0   24160  211.3375       B5        S    2
# 1                   1            2  113781  151.5500  C22 C26        S   11
# 2                   1            2  113781  151.5500  C22 C26        S  NaN
# 3                   1            2  113781  151.5500  C22 C26        S  NaN
# 4                   1            2  113781  151.5500  C22 C26        S  NaN
# ...               ...          ...     ...       ...      ...      ...  ...
# 1304                1            0    2665   14.4542      NaN        C  NaN
# 1305                1            0    2665   14.4542      NaN        C  NaN
# 1306                0            0    2656    7.2250      NaN        C  NaN
# 1307                0            0    2670    7.2250      NaN        C  NaN
# 1308                0            0  315082    7.8750      NaN        S  NaN
#
#            corpo                          destino
# 0     160.809917                     St Louis, MO
# 1     160.809917  Montreal, PQ / Chesterville, ON
# 2     160.809917  Montreal, PQ / Chesterville, ON
# 3     135.000000  Montreal, PQ / Chesterville, ON
# 4     160.809917  Montreal, PQ / Chesterville, ON
# ...          ...                              ...
# 1304  328.000000                              NaN
# 1305  160.809917                              NaN
# 1306  304.000000                              NaN
# 1307  160.809917                              NaN
# 1308  160.809917                              NaN
#
# [1309 rows x 15 columns]

# %% [markdown]
# ### 2.3.3.2 Tarifas Ausentes
# Para os dados ausentes da coluna tarifaserá feita a substituição dos dados vazios pela média de preço das tarifas na época.

# %%
df.fillna(df.mean())
# Out:
#       id_passageiro  classe  sobreviveu  \
# 0                 1       1           1
# 1                 2       1           1
# 2                 3       1           0
# 3                 4       1           0
# 4                 5       1           0
# ...             ...     ...         ...
# 1304           1305       3           0
# 1305           1306       3           0
# 1306           1307       3           0
# 1307           1308       3           0
# 1308           1309       3           0
#
#                                                  nome    sexo      idade  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.000000
# 1                      Allison, Master. Hudson Trevor    male   1.000000
# 2                        Allison, Miss. Helen Loraine  female   2.000000
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.000000
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.000000
# ...                                               ...     ...        ...
# 1304                             Zabour, Miss. Hileni  female  15.000000
# 1305                            Zabour, Miss. Thamine  female  29.897706
# 1306                        Zakarian, Mr. Mapriededer    male  27.000000
# 1307                              Zakarian, Mr. Ortin    male  27.000000
# 1308                               Zimmerman, Mr. Leo    male  29.000000
#
#       irmaos_conjuges  pais_filhos bilhete    tarifa   cabine embarque bote  \
# 0                   0            0   24160  211.3375       B5        S    2
# 1                   1            2  113781  151.5500  C22 C26        S   11
# 2                   1            2  113781  151.5500  C22 C26        S  NaN
# 3                   1            2  113781  151.5500  C22 C26        S  NaN
# 4                   1            2  113781  151.5500  C22 C26        S  NaN
# ...               ...          ...     ...       ...      ...      ...  ...
# 1304                1            0    2665   14.4542      NaN        C  NaN
# 1305                1            0    2665   14.4542      NaN        C  NaN
# 1306                0            0    2656    7.2250      NaN        C  NaN
# 1307                0            0    2670    7.2250      NaN        C  NaN
# 1308                0            0  315082    7.8750      NaN        S  NaN
#
#            corpo                          destino
# 0     160.809917                     St Louis, MO
# 1     160.809917  Montreal, PQ / Chesterville, ON
# 2     160.809917  Montreal, PQ / Chesterville, ON
# 3     135.000000  Montreal, PQ / Chesterville, ON
# 4     160.809917  Montreal, PQ / Chesterville, ON
# ...          ...                              ...
# 1304  328.000000                              NaN
# 1305  160.809917                              NaN
# 1306  304.000000                              NaN
# 1307  160.809917                              NaN
# 1308  160.809917                              NaN
#
# [1309 rows x 15 columns]

# %% [markdown]
# ### 2.3.3.3 Portos de Embarque Ausentes
# Para os dados ausentes da coluna embarqueserá feita a remoção dos dados vazios.

# %%
df[df['embarque'].notnull()]
# Out:
#       id_passageiro  classe  sobreviveu  \
# 0                 1       1           1
# 1                 2       1           1
# 2                 3       1           0
# 3                 4       1           0
# 4                 5       1           0
# ...             ...     ...         ...
# 1304           1305       3           0
# 1305           1306       3           0
# 1306           1307       3           0
# 1307           1308       3           0
# 1308           1309       3           0
#
#                                                  nome    sexo  idade  \
# 0                       Allen, Miss. Elisabeth Walton  female   29.0
# 1                      Allison, Master. Hudson Trevor    male    1.0
# 2                        Allison, Miss. Helen Loraine  female    2.0
# 3                Allison, Mr. Hudson Joshua Creighton    male   30.0
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female   25.0
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female   15.0
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male   27.0
# 1307                              Zakarian, Mr. Ortin    male   27.0
# 1308                               Zimmerman, Mr. Leo    male   29.0
#
#       irmaos_conjuges  pais_filhos bilhete    tarifa   cabine embarque bote  \
# 0                   0            0   24160  211.3375       B5        S    2
# 1                   1            2  113781  151.5500  C22 C26        S   11
# 2                   1            2  113781  151.5500  C22 C26        S  NaN
# 3                   1            2  113781  151.5500  C22 C26        S  NaN
# 4                   1            2  113781  151.5500  C22 C26        S  NaN
# ...               ...          ...     ...       ...      ...      ...  ...
# 1304                1            0    2665   14.4542      NaN        C  NaN
# 1305                1            0    2665   14.4542      NaN        C  NaN
# 1306                0            0    2656    7.2250      NaN        C  NaN
# 1307                0            0    2670    7.2250      NaN        C  NaN
# 1308                0            0  315082    7.8750      NaN        S  NaN
#
#       corpo                          destino
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1307 rows x 15 columns]

# %%
df['Total_parentes'] = df['irmaos_conjuges'] + df['pais_filhos']

# %%
df
# Out:
#       id_passageiro  classe  sobreviveu  \
# 0                 1       1           1
# 1                 2       1           1
# 2                 3       1           0
# 3                 4       1           0
# 4                 5       1           0
# ...             ...     ...         ...
# 1304           1305       3           0
# 1305           1306       3           0
# 1306           1307       3           0
# 1307           1308       3           0
# 1308           1309       3           0
#
#                                                  nome    sexo  idade  \
# 0                       Allen, Miss. Elisabeth Walton  female   29.0
# 1                      Allison, Master. Hudson Trevor    male    1.0
# 2                        Allison, Miss. Helen Loraine  female    2.0
# 3                Allison, Mr. Hudson Joshua Creighton    male   30.0
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female   25.0
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female   15.0
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male   27.0
# 1307                              Zakarian, Mr. Ortin    male   27.0
# 1308                               Zimmerman, Mr. Leo    male   29.0
#
#       irmaos_conjuges  pais_filhos bilhete    tarifa   cabine embarque bote  \
# 0                   0            0   24160  211.3375       B5        S    2
# 1                   1            2  113781  151.5500  C22 C26        S   11
# 2                   1            2  113781  151.5500  C22 C26        S  NaN
# 3                   1            2  113781  151.5500  C22 C26        S  NaN
# 4                   1            2  113781  151.5500  C22 C26        S  NaN
# ...               ...          ...     ...       ...      ...      ...  ...
# 1304                1            0    2665   14.4542      NaN        C  NaN
# 1305                1            0    2665   14.4542      NaN        C  NaN
# 1306                0            0    2656    7.2250      NaN        C  NaN
# 1307                0            0    2670    7.2250      NaN        C  NaN
# 1308                0            0  315082    7.8750      NaN        S  NaN
#
#       corpo                          destino  Total_parentes
# 0       NaN                     St Louis, MO               0
# 1       NaN  Montreal, PQ / Chesterville, ON               3
# 2       NaN  Montreal, PQ / Chesterville, ON               3
# 3     135.0  Montreal, PQ / Chesterville, ON               3
# 4       NaN  Montreal, PQ / Chesterville, ON               3
# ...     ...                              ...             ...
# 1304  328.0                              NaN               1
# 1305    NaN                              NaN               1
# 1306  304.0                              NaN               0
# 1307    NaN                              NaN               0
# 1308    NaN                              NaN               0
#
# [1309 rows x 16 columns]

# %% [markdown]
# Faixa Etaria

# %%
df["idade"].mean()
# Out:
# 29.89770554493308

# %% [markdown]
# ## 3. Análise dos Dados

# %% [markdown]
# ### 3.1. Qual é o número de Sobreviventes?

# %%
df_mask=df['sobreviveu']==1
filtered_df = df[df_mask]
resultado = filtered_df.sum()
resultado['sobreviveu']
# Out:
# 500

# %% [markdown]
# ### 3.2. Homens ou mulheres tiveram mais chances de sobreviver?

# %%
df['sexo'].value_counts()
# Out:
# male      843
# female    466
# Name: sexo, dtype: int64

# %% [markdown]
# #### Homens tiveram mais chances de sobreviver.

# %% [markdown]
# ## 3.3. Qual classe social teve mais sobreviventes?

# %%
df['classe'].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: classe, dtype: int64

# %% [markdown]
# #### Classe 3(Baixa) teve mais chances de sobreviver.

# %% [markdown]
# ## 3.4. Qual faixa etária teve mais chances de sobreviver?

# %%
df['idade'].value_counts()
# Out:
# 24.0    48
# 22.0    43
# 21.0    42
# 30.0    40
# 18.0    39
#         ..
# 80.0     1
# 67.0     1
# 74.0     1
# 76.0     1
# 66.0     1
# Name: idade, Length: 73, dtype: int64

# %%
24 foi a Faixa etária que mais teve sobreviventes.
